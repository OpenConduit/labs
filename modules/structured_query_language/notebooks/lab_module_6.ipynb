# %% [markdown]
# # Lab Module 6: Set Operators
#
# (Run the below cell first, to ensure connectivity)

# %%
# %load_ext sql

# %sql postgresql://admin:password@postgres:5432/postgres

# %% [markdown]
# ## Challenge 1: The Master State List
# - **Context**: The marketing team wants a simple list of every Brazilian state where the platform has a presence, whether it's a buyer or a seller.
# - **Task**: Write a query that combines the `customer_state` from the `customers` table and `seller_state` from the `sellers` table. Ensure the final list contains **unique** state codes only.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 2: Total Geographical Footprint
# - **Context**: The infrastructure team is calculating the total data load for location services. They need to process every instance of a state appearing in our database, including duplicates, to estimate traffic volume.
# - **Task**: Write a query that combines `customer_state` and `seller_state` again, but this time retain **all** rows, including duplicates.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 3: Consolidating Zip Codes
# - **Context**: We need a unified list of all postal codes (zip code prefixes) used in the system to update our geo-mapping tool.
# - **Task**: Write a query to select the `customer_zip_code_prefix` from `customers` and `seller_zip_code_prefix` from `sellers`. Use `UNION` to remove duplicates and create a single column list.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 4: Identifying "Hotspot" Cities
# - **Context**: The sales team identifies "Hotspots" as cities where we have both active buyers and active sellers. This allows for faster local shipping.
# - **Task**: Write a query that finds the city names (`customer_city`) and states (`customer_state`) that exist in the `customers` table AND also exist as `seller_city` and `seller_state` in the `sellers` table.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 5: Expansion Opportunities (Gap Analysis)
# - **Context**: We want to find "Consumer-Only" markets. These are cities where we have customers buying goods, but no local sellers to fulfill them.
# - **Task**: Write a query using `EXCEPT` to list cities (`customer_city`) and states (`customer_state`) found in the `customers` table but not found in the `sellers` table.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 6: Creating a User Directory with Labels
# - **Context**: The support team needs a unified contact list of IDs, but they need to know if the ID belongs to a Customer or a Seller.
# - **Task**: Write a query that selects `customer_id` and a hardcoded string labeled 'Customer' from the `customers` table. Combine this with `seller_id` and a hardcoded string labeled 'Seller' from the `sellers` table. Use `UNION ALL`.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 7: Targeted Regional Analysis
# - **Context**: We are specifically auditing the state of Rio de Janeiro ('RJ'). We need a list of all cities in 'RJ' that have either customers OR sellers.
# - **Task**: Write a query that selects distinct `customer_city` from `customers` where the `customer_state` is 'RJ', combined with distinct `seller_city` from `sellers` where the `seller_state` is 'RJ'. Use `UNION`.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 8: High Volume Hubs
# - **Context**: Management wants to focus on "High Volume" hubs. A hub is defined as a city having either more than 2,000 customers OR more than 50 sellers.
# - **Task**: Write two queries using `GROUP BY` and `HAVING`: one to find `customer_city` with > 2,000 `customers`, and one to find `seller_city` with > 50 `sellers`. Combine these lists using `UNION`.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 9: Sorted Geographic Report
# - **Context**: Generating a report often requires a specific sort order. The report should list all unique cities and states from both customers and sellers, sorted alphabetically by State first, then City.
# - **Task**: Write a `UNION` query to get all unique city and state pairs (from `customers` and `sellers`). Add an `ORDER BY` clause at the very end to sort the final combined result by `state` (ascending) and then `city` (ascending).

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 10: The "Exclusive" Markets (Symmetric Difference)
# - **Context**: We need to find cities that are "unbalanced"—meaning they have EITHER customers only OR sellers only, but not both. (This is the opposite of the "Hotspots" from Challenge 4).
# - **Task**:
#     - 1. Select cities/states from `customers` EXCEPT those in `sellers`.
#     - 2. Select cities/states from `sellers` EXCEPT those in `customers`.
#     - 3. Combine these two results using `UNION`.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# # Lab Module 4: Aggregating and Grouping
#
# (Run the below cell first, to ensure connectivity)

# %%
# %load_ext sql

# %sql postgresql://admin:password@postgres:5432/postgres

# %% [markdown]
# ## Challenge 1: The Total Order Count
# - **Context**: The operations team needs a quick status check on the total volume of orders processed since the platform launched.
# - **Task**: Write a query to count the total number of rows in the `orders` table. Alias the result as `total_orders`.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 2: Calculating Total Revenue
# - **Context**: Finance needs to know the gross merchandise value (GMV) generated by the platform to date.
# - **Task**: Calculate the total sum of the `price` column from the `order_items` table. Alias the result as `total_revenue`.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 3: Average Freight Costs
# - **Context**: The logistics team is analyzing shipping efficiency. They want to know the average cost customers pay for shipping per item.
# - **Task**: Calculate the average `freight_value` from the `order_items` table. Alias it as `avg_freight`.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 4: Extreme Product Weights
# - **Context**: The warehouse team needs to calibrate their scales. They need to know the lightest and heaviest items in the inventory.
# - **Task**: Find the minimum and maximum `product_weight_g` from the `products` table. Alias them as `min_weight` and `max_weight`.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 5: Counting Distinct Locations
# - **Context**: To understand our geographic reach, marketing wants to know how many unique cities our sellers operate from.
# - **Task**: Count the number of distinct `seller_city` entries in the `sellers` table. Alias as `unique_seller_cities`.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 6: Customers by State
# - **Context**: We need to identify our largest markets. The marketing team wants a breakdown of the user base by region.
# - **Task**: Count the number of `customer_id` for each `customer_state` in the `customers` table. Display the state and the count, sorted by the count in descending order.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 7: Orders by Status
# - **Context**: The technical support team is monitoring the pipeline for bottlenecks (e.g., stuck orders).
# - **Task**: Count how many `order_id` exist for each `order_status` in the `orders`. Sort alphabetically by status.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 8: Revenue per Seller
# - **Context**: We want to identify our top-performing partners based on sales volume.
# - **Task**: Calculate the total revenue (`SUM(price)`) for each `seller_id` in the `order_items` table. Sort by revenue descending and show the top 10.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 9: Product Dimensions by Category
# - **Context**: The packaging team wants to optimize box sizes for different product categories.
# - **Task**: Calculate the average `product_length_cm`, `product_height_cm`, and `product_width_cm` for each `product_category_name` in the `products` table.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 10: Daily Order Volume
# - **Context**: Traffic analysis needs to know which days had the highest server load.
# - **Task**: Count the number of `order_id` placed on each date from the `orders` table. You will need to cast `order_purchase_timestamp` to a DATE to ignore the time component. Order by date descending.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 11: Identifying Active Sellers
# - **Context**: We are auditing the marketplace and want to filter out low-volume sellers.
# - **Task**: List all `seller_ids` that have sold more than 50 distinct items (`order_item_id`) from the `order_items` table.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 12: High-Value Orders
# - **Context**: Fraud detection wants to manually review unusually large transactions.
# - **Task**: Find the total `price` for each `order_id` from the `order_items` table. Only return orders where the total `price` exceeds 500.00.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 13: Cities with Multiple Sellers
# - **Context**: The partner manager wants to visit cities that have a high concentration of sellers.
# - **Task**: List `seller_city` and the count of `seller_id` for cities that have at least 10 sellers, from the `sellers` table. Order by the count descending.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 14: Categories with Heavy Products
# - **Context**: Logistics wants to review shipping contracts for categories that are generally heavy.
# - **Task**: Find `product_category_names` where the average `product_weight_g` is greater than 2000 grams, from the `products` table.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 15: Validating Shipping Limits
# - **Context**: We need to find orders that contain many items, as they might require split shipments.
# - **Task**: Return the `order_id` for any order containing more than 5 items, from the `order_items` table.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 16: Active Sellers in SP (WHERE vs HAVING)
# - **Context**: We want to find top sellers specifically in the state of São Paulo ('SP').
# - **Task**:
#     - Filter the `sellers` table for `seller_state` 'SP'.
#     - Group by `seller_city`.
#     - Only show cities with more than 5 sellers.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 17: Excluding NULL Categories
# - **Context**: Data Quality wants to analyze product categories, but there are some products with missing category names.
# - **Task**: Count the number of rows per `product_category_name` in the `products` table. You must exclude rows where the category is NULL using WHERE before grouping.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 18: The Alias Trap (WHERE)
# - **Context**: A junior analyst is trying to filter by a calculated column alias in the WHERE clause and getting an error. You need to show them the right way.
# - **Task**: Calculate the total `price` per `order_id` for orders in 2018 from the `order_items` table. Instruction: You need to filter `shipping_limit_date` for the year 2018 first. Do NOT try to use the alias of the sum in the WHERE clause.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 19: The Alias Trap (HAVING)
# - **Context**: We want to find orders with a high average item price.
# - **Task**: Calculate the average `price` per `order_id` from the `order_items` table. Filter to show only those where the average is greater than 100. Instruction: Try to use the alias `avg_price` in the HAVING clause. (Note: In standard SQL this fails, though some engines allow it. For this lab, assume standard strict mode: repeat the aggregate function).

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 20: The "Final Boss" Report
# - **Context**: Management wants a summary of "Big Ticket" categories.
# - **Task**:
#     - Select the `product_category_name`.
#     - Calculate the average `product_weight_g`.
#     - Filter out categories where the name starts with 'a' (just as an arbitrary exclusion rule).
#     - Group by category.
#     - Keep only categories where the average weight is > 500g.
#     - Order by average weight descending.
#     - From the `products` table.

# %%
# %%sql
# -- Write your solution here

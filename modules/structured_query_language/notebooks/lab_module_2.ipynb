# %% [markdown]
# # Lab Module 2: Filtering and Sorting
#
# (Run the below cell first, to ensure connectivity)

# %%
# %load_ext sql

# %sql postgresql://admin:password@postgres:5432/postgres

# %% [markdown]
# ## Challenge 1: The Specific State
# - **Context**: The marketing team is launching a pilot campaign in Rio de Janeiro (RJ).
# - **Task**: Write a query to list **all** columns for customers located in the `customer_state` of 'RJ', from the `customers` table.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 2: Heavy Products
# - **Context**: The logistics team needs to identify heavy items to negotiate better shipping rates.
# - **Task**: List the `product_id` and `product_weight_g` for **all** products where `product_weight_g` is more than 3000 grams. from the `products` table.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 3: Excluding Delivered Orders
# - **Context**: Customer Support wants to focus only on active orders that have not yet been finalized.
# - **Task**: Retrieve **all** columns from the `orders` table where the `order_status` is NOT 'delivered'.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 4: Low Value Items
# - **Context**: We are auditing low-value transactions to check for pricing errors.
# - **Task**: Select the `order_id`, `product_id`, and `price` from `order_items` where the `price` is strictly less than 10.00.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 5: Precise Location Targeting (AND)
# - **Context**: A local courier service in Campinas, SP, is offering a discount.
# - **Task**: Select **all** columns for `sellers` who are in the `seller_state` 'SP' AND the `seller_city` 'campinas'.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 6: Multiple Statuses (OR)
# - **Context**: The warehouse manager needs a list of orders that are either being processed or have been shipped.
# - **Task**: Retrieve the `order_id` and `order_status` from the `orders` table, where the `order_status` is 'shipped' OR 'processing'.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 7: Weight Ranges (BETWEEN)
# - **Context**: We are creating a "Medium Weight" category for shipping boxes.
# - **Task**: Select `product_id` and `product_weight_g` from the `products` table, where `product_weight_g` is between 1000 and 2000 grams (inclusive).

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 8: Date Ranges
# - **Context**: Accounting needs to audit all orders placed during the first week of 2018.
# - **Task**: Select `order_id` and `order_purchase_timestamp` from the `orders` table that were placed between '2018-01-01' and '2018-01-07'.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 9: Specific Categories (IN)
# - **Context**: We are analyzing the "Home & Living" segment.
# - **Task**: Select `product_id` and `product_category_name` from the `products` table that are in these three `product_category_name`s: 'cama_mesa_banho', 'moveis_decoracao', 'utilidades_domesticas'.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 10: Excluding Regions (NOT IN)
# - **Context**: We are analyzing sellers located outside of the major southeastern states.
# - **Task**: Select **all** `seller` columns where the `seller_state` is NOT IN ('SP', 'RJ', 'MG').

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 11: Broad Pattern Matching (LIKE %)
# - **Context**: The catalog team wants to find all "Toy" related categories.
# - **Task**: Select **distinct** `product_category_name` from `products` where the `product_category_name` starts with 'brinquedos'.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 12: Internal Pattern Matching
# - **Context**: We need to find all "furniture" categories, but the naming convention varies (e.g., office furniture, bedroom furniture).
# - **Task**: Select **distinct** `product_category_name` from `products` where the `product_category_name` contains the text 'moveis'.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 13: Finding Missing Data (IS NULL)
# - **Context**: We need to identify orders that were never shipped to the carrier.
# - **Task**: Select `order_id` and `order_status` for `orders` where `order_delivered_carrier_date` IS NULL.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 14: Confirming Data Presence (IS NOT NULL)
# - **Context**: We want to analyze only orders that have been successfully delivered to the customer.
# - **Task**: Select `order_id` and `order_delivered_customer_date` from the `orders` table, where the `order_delivered_customer_date` is NOT NULL.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 15: Sorting Text (ORDER BY)
# - **Context**: We need an alphabetical list of all cities where we have sellers.
# - **Task**: Select **distinct** `seller_city` from the `sellers` table and sort them alphabetically (A-Z).

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 16: Sorting Numbers (DESC)
# - **Context**: We want to display the most expensive items in our catalog first.
# - **Task**: Select `product_id` and `price` from `order_items`. Sort the results by `price` from highest to lowest.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 17: High Value, High Freight
# - **Context**: The finance team is auditing orders that are both expensive to buy and expensive to ship.
# - **Task**: Select `order_id`, `price`, and `freight_value` from `order_items` where `price` is greater than 100 AND `freight_value` is greater than 50.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 18: Big and Bulky
# - **Context**: Warehouse optimization needs to find products that are both heavy and large in volume.
# - **Task**: Select `product_id` from `products` where `product_weight_g` > 10000 (10kg) AND `product_height_cm` > 50.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 19: Late Deliveries
# - **Context**: We need to compensate customers whose orders arrived later than promised.
# - **Task**: Select `order_id`, `order_estimated_delivery_date`, and `order_delivered_customer_date` from `orders` where the `order_delivered_customer_date` is greater than `order_estimated_delivery_date`.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 20: The Priority Filter (Multi-Column Sorting)
# - **Context**: The Operations Director wants a prioritized list of orders that are 'invoiced' but not yet shipped, sorted by the oldest purchase first.
# - **Task**: Select `order_id`, `order_status`, and `order_purchase_timestamp` from the `orders` table, where `status` is 'invoiced'. Sort the results by `order_purchase_timestamp` (oldest first), then by `order_id` (ascending).

# %%
# %%sql
# -- Write your solution here

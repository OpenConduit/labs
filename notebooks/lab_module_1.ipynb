# %% [markdown]
# # Lab Module 1: The SELECT Statement
#
# (Run the below cell first, to ensure connectivity)

# %%
# %load_ext sql

# %sql postgresql://admin:password@postgres:5432/postgres

# %% [markdown]
# ## Challenge 1: The "Hello World" of Data
# - Context: You have just been granted access to the Olist database. Before running complex analysis, you need to verify that you can read the raw customer data.
# - Task: Write a query to select **all** columns and **all** rows from the `customers` table.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 2: Reducing Noise (Column Selection)
# - Context: The products table contains dimension details (weight, length) that are irrelevant for your current report. You only need the product identifiers and their category names.
# - Task: Write a query to select **only** the `product_id` and `product_category_name` columns from the `products` table.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 3: Sampling Data (The LIMIT Clause)
# - Context: The order_items table contains millions of rows. Querying the entire table causes the database to hang. You need to quickly inspect the structure of the data without loading everything.
# - Task: Select **all** columns from the `order_items` table, but **limit** the results to only the first 100 rows.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 4: Auditing Order Statuses
# - Context: The logistics team wants to know the range of possible lifecycles an order can go through (e.g., 'delivered', 'canceled'). They do not want duplicates, just the unique list of statuses.
# - Task: Write a query to list the **distinct** `order_status` values found in the `orders` table.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 5: Auditing Product Categories
# - Context: The warehouse manager is looking to understand the different unique product categories that currently exist.
# - Task: Select the **distinct** `product_category_name` values from the `products` table.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 6: Seller Geography (Multi-Column Selection)
# - Context: To plan a new shipping hub, we need to know the location of our sellers. You need to extract just their city and state.
# - Task: Select the `seller_city` and `seller_state` columns from the `sellers` table. **Do not use DISTINCT yet**, just list the raw data.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 7: Unique Seller Locations (Multi-Column DISTINCT)
# - Context: The previous list contained too many duplicates (many sellers live in the same city). Now, generate a unique list of city-state pairs where we have sellers.
# - Task: Write a query to select **distinct** combinations of `seller_city` and `seller_state` from the `sellers` table.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 8: Previewing Sellers
# - Context: The Customer Experience team wants to see the listing of sellers. They need to see seller's id, city and state.
# - Task: Select **distinct** combinations of `seller_id`, `seller_city`, and `seller_state` from the `sellers` table, **limiting** the results to 20 rows.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 9: Documenting Code
# - Context: You are handing this query off to a junior analyst. You need to select data from order_items but also include a comment explaining that the data is strictly for audit purposes.
# - Task: Select `order_id` and `price` from `order_items` with a **limit** of 10. Add a single-line **comment** above the query saying "Audit Sampling".

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 10: Understanding Customer IDs (Edge Case)
# - Context: In Olist, customer_id is a tracking key per order, while customer_unique_id identifies the actual human. To understand this difference, you need to view them side-by-side.
# - Task: Select `customer_id`, `customer_unique_id`, and `customer_state` from the `customers` table, **limit** the results to 50 entries.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 11: Product Category Audit
# - Context: The marketing team is reviewing product catalog completeness. They need to see which categories exist in the products table.
# - Task: Select **all** columns from the `products` table, but **limit** the results to the first 15 rows to quickly verify the data structure.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 12: Shipping Limit Dates
# - Context: The operations team needs to check the shipping_limit_date for order items to ensure systems are recording timestamps correctly.
# - Task: Select only the `order_id` and `shipping_limit_date` from the `order_items` table. **Limit** the output to 5 rows.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 13: Unique Customer Cities
# - Context: We want to know the reach of our platform. Generate a list of all unique cities where our customers reside.
# - Task: Write a query to select **distinct** `customer_city` values from the `customers` table.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 14: Order Approval Times
# - Context: The e-commerce team is wanting to know the ranges of time that orders are getting approved at.
# - Task: Select the `order_approved_at` column from the `orders` table. Use **DISTINCT** to see only the unique times available in the dataset.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 15: Freight Value Inspection
# - Context: Logistics wants to inspect freight costs. They need to see the freight_value alongside the price for a sample of items.
# - Task: Select `price` and `freight_value` from the `order_items` table, **limiting** the results to 50 rows.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 16: Initial Order Data
# - Context: You are investigating the orders table structure. You specifically need to see the order_purchase_timestamp and order_delivered_customer_date.
# - Task: Select `order_id`, `order_purchase_timestamp`, and `order_delivered_customer_date` from the `orders` table. **Limit** to 10 rows.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 17: Seller Zip Codes
# - Context: To assist in geolocation mapping, we need a list of unique zip code prefixes where our sellers are located.
# - Task: Select **distinct** `seller_zip_code_prefix` from the `sellers` table.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 18: Product Dimensions
# - Context: Warehouse planning requires knowledge of product sizes. Retrieve the dimensions for a sample of products.
# - Task: Select `product_length_cm`, `product_height_cm`, and `product_width_cm` from the `products` table. **Limit** to 25 rows.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 19: Freight Price Analysis
# - Context: The finance team wants to see the variety of freight values for items.
# - Task: Select the **distinct** `freight_value` values from the `order_items` table.

# %%
# %%sql
# -- Write your solution here

# %% [markdown]
# ## Challenge 20: Comprehensive Order Item Review
# - Context: For a detailed audit, you need to pull multiple financial identifiers for order items.
# - Task: Select `order_id`, `product_id`, `seller_id`, and `price` from the `order_items` table. **Limit** the output to 100 rows.

# %%
# %%sql
# -- Write your solution here
